# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
import scipy.optimize as opt
import scipy.signal as sig
import scipy.integrate as sciint
from functools import partial
from itertools import cycle
import os

# Mine
from wilson_cowan_2d.simulations import concrete_wc_kernel as wck
from wilson_cowan_2d.simulations import wc_params as wcp
from wilson_cowan_2d.simulations.nonlinear_functions import decreasing_exponential
from wilson_cowan_2d.analysis.nulclines import calc_cross_points, calc_nulclines_crosspoints

from IPython.display import HTML, clear_output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
report_path = "/home/nicolasjudd/school_notes/neural/final_report/"
img_path = os.path.join(report_path, 'img')

# %%
dots = ["⢀⠀","⡀⠀","⠄⠀","⢂⠀","⡂⠀","⠅⠀",
"⢃⠀","⡃⠀","⠍⠀","⢋⠀","⡋⠀","⠍⠁","⢋⠁","⡋⠁","⠍⠉","⠋⠉",
"⠋⠉","⠉⠙","⠉⠙","⠉⠩","⠈⢙","⠈⡙","⢈⠩","⡀⢙","⠄⡙",
"⢂⠩","⡂⢘","⠅⡘","⢃⠨","⡃⢐","⠍⡐","⢋⠠","⡋⢀","⠍⡁",
"⢋⠁","⡋⠁","⠍⠉","⠋⠉","⠋⠉","⠉⠙","⠉⠙","⠉⠩","⠈⢙",
"⠈⡙","⠈⠩","⠀⢙","⠀⡙","⠀⠩","⠀⢘","⠀⡘","⠀⠨","⠀⢐",
"⠀⡐","⠀⠠","⠀⢀","⠀⡀"
]
dot_cycle = cycle(dots)

# %%
def make_counter(end, rate=20):
    e = end
    counter = 0
    dot_cycle = cycle(dots)
    def count_time(t):
        nonlocal counter
        counter += 1
        if counter % rate == 0:
            clear_output(wait=True)
            print(next(dot_cycle), f"Time Step: {int(t):0>4}/{int(e):0>4}",
                  f"Percent Done: {t/e:>.1%}")

    return count_time

# %%
τ = 2
τe = 1
τi = τ * τe

σ = 1.45
σe = 10
σi = σ* σe

param = wcp.DefaultParams(τ = np.array([τe, τi]), η = 1, size = 2**9, σ=np.array([σe,σi]))
# param.Θ = np.array([0.08, 0.4])

u,v,cps = calc_nulclines_crosspoints(param)
_ = plt.plot(*u)
_ = plt.plot(*v)
_ = plt.scatter(*cps, c='r')
_ = plt.xlim(-0.1, 0.5)
_ = plt.ylim(-0.1, 0.5)
print(cps)

u_str = cps[0,-1]
v_str = cps[1,-1]

u_str = 0
v_str = 0


x,y = np.ogrid[-param.size/2:param.size/2, -param.size/2:param.size/2]

radius = 10
u = (x - param.size//2)**2 + (y + param.size//2)**2 <= radius ** 2
# u[param.size//2-s:param.size//2+s, param.size//2-s:param.size//2+s] = 1
v = v_str*np.ones((param.size, param.size))

#  inp = (u3, v3, u3, 0)

inp = (u, v)
# Out:
# /home/nicolasjudd/school_notes/neural/py_projs/2D_wilson_cowan/src/wilson_cowan_2d/simulations/nonlinear_functions.py:10: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + nexp(-β * x))
# [[0.005      0.083      0.424     ]
#  [0.00394725 0.00396604 0.20470882]]

# %%
end = 100
step = end/(4*param.size)
count = make_counter(end, rate=5)
# res = wck.WCDecExpTravelNonLocal2D(inp, param)((0, end), t_eval=np.arange(0, end, step))
res = wck.WCDecExpTravelNonLocal2D(inp, param)((0, end), t_eval=np.arange(0, end, step), args=(count,))
# res = wck.WCDecExpTravelNonLocal2D(inp, param)((0, end), args=(count,))

print(res.message)
# Out:
# ⠀⡘ Time Step: 0099/0100 Percent Done: 99.9%
# The solver successfully reached the end of the integration interval.

# %%
u, v = res.y.T.reshape(2, len(res.t), param.size, param.size)

# %%
# fig = plt.figure(figsize=(16,4))

# _ = plt.imshow(u, vmin=0, vmax=0.25)


# test = res.u.ravel().reshape(len(res), param.size, param.size)
test_list = list(u)
plt.imshow(u[:, :, param.size//2], vmin=0, vmax=0.25)

# %%
fig, ax = plt.subplots()
vmin=0
vmax=0.5

im1 = ax.imshow(test_list[0], vmin=vmin, vmax=vmax)
cnt = make_counter(len(test_list), rate=1)

def update_gif(i, plot, ims):
    _ = plot.set_data(test_list[i])
    cnt(i)
    return plot,

anim = FuncAnimation(fig, partial(update_gif, plot=im1, ims=test_list)
                     ,frames=range(len(test_list)),interval=1000/120, blit=True)

HTML(anim.to_html5_video())
# Out:
# ⢋⠁ Time Step: 2047/2048 Percent Done: 100.0%
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# fig = plt.figure()
# ax = plt.gca()
# plt.imshow(res.u[:,:param.size].T, aspect='equal', vmin=0, vmax=0.5)
# plt.colorbar()

# fig_name = f"nonlocal_wave_sig={σ}_tau={τ}.png"
# plt.text(0.01, 0.05, f"σ = {σ}",fontsize=20, color='white', ha='left', va='bottom', transform=ax.transAxes)
# plt.text(0.01, 0.125, f"τ = {τ}",fontsize=20, color='white', ha='left', va='bottom', transform=ax.transAxes)
# fig.tight_layout()
# # plt.savefig(os.path.join(img_path, fig_name), bbox_inches='tight')

# %%
anim.save(os.path.join(img_path, f"Traveling_Pulse_512x512_sig--1.45_tau--2.gif"))
# Out:
# ⠍⠁ Time Step: 2047/2048 Percent Done: 100.0%
