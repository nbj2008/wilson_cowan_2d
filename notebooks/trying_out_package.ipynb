# %%
import numpy as np
from matplotlib import pyplot as plt
from importlib import reload

# %%
import wilson_cowan_2d as wc2d
import wilson_cowan_2d.systems.concrete_wc_kernel as wck

# %%
size = 1
σ = np.array([205, 2])
τ = 0.3
params = wck.DefaultParams(τ = np.array([1, 1/τ]).reshape([2,1]) , size=size)

test = wck.WCUnif(0.2*np.ones(size), 
                  0.2*np.ones(size), params)

res = test((0,20))

_ = plt.plot(res.us, res.vs)
# _ = plt.ylim(0, 0.3)
# _ = plt.xlim(0, 0.5)

# %%
_ = plt.plot(res.t, res.us)
